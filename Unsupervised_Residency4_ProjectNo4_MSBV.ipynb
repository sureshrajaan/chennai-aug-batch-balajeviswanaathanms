# %%
#Import all the necessary modfrom pandas import read_csv
import seaborn as sns
import numpy as np
import pandas as pd
# importing ploting libraries
import matplotlib.pyplot as plt

# %% [markdown]
# 1.	EDA & Pre-processing (Make sure to remove all non-numeric entries from numeric columns) – 2.5 points

# %%
df=pd.read_csv("cars-dataset.csv")
df
# Out:
#                               car name  cyl   disp   hp    wt   acc  yr   mpg
# 0            chevrolet chevelle malibu    8  307.0  130  3504  12.0  70  18.0
# 1                    buick skylark 320    8  350.0  165  3693  11.5  70  15.0
# 2                   plymouth satellite    8  318.0  150  3436  11.0  70  18.0
# 3                        amc rebel sst    8  304.0  150  3433  12.0  70  16.0
# 4                          ford torino    8  302.0  140  3449  10.5  70  17.0
# 5                     ford galaxie 500    8  429.0  198  4341  10.0  70  15.0
# 6                     chevrolet impala    8  454.0  220  4354   9.0  70  14.0
# 7                    plymouth fury iii    8  440.0  215  4312   8.5  70  14.0
# 8                     pontiac catalina    8  455.0  225  4425  10.0  70  14.0
# 9                   amc ambassador dpl    8  390.0  190  3850   8.5  70  15.0
# 10                 dodge challenger se    8  383.0  170  3563  10.0  70  15.0
# 11                  plymouth 'cuda 340    8  340.0  160  3609   8.0  70  14.0
# 12               chevrolet monte carlo    8  400.0  150  3761   9.5  70  15.0
# 13             buick estate wagon (sw)    8  455.0  225  3086  10.0  70  14.0
# 14               toyota corona mark ii    4  113.0   95  2372  15.0  70  24.0
# 15                     plymouth duster    6  198.0   95  2833  15.5  70  22.0
# 16                          amc hornet    6  199.0   97  2774  15.5  70  18.0
# 17                       ford maverick    6  200.0   85  2587  16.0  70  21.0
# 18                        datsun pl510    4   97.0   88  2130  14.5  70  27.0
# 19        volkswagen 1131 deluxe sedan    4   97.0   46  1835  20.5  70  26.0
# 20                         peugeot 504    4  110.0   87  2672  17.5  70  25.0
# 21                         audi 100 ls    4  107.0   90  2430  14.5  70  24.0
# 22                            saab 99e    4  104.0   95  2375  17.5  70  25.0
# 23                            bmw 2002    4  121.0  113  2234  12.5  70  26.0
# 24                         amc gremlin    6  199.0   90  2648  15.0  70  21.0
# 25                           ford f250    8  360.0  215  4615  14.0  70  10.0
# 26                           chevy c20    8  307.0  200  4376  15.0  70  10.0
# 27                          dodge d200    8  318.0  210  4382  13.5  70  11.0
# 28                            hi 1200d    8  304.0  193  4732  18.5  70   9.0
# 29                        datsun pl510    4   97.0   88  2130  14.5  71  27.0
# ..                                 ...  ...    ...  ...   ...   ...  ..   ...
# 368           chevrolet cavalier wagon    4  112.0   88  2640  18.6  82  27.0
# 369          chevrolet cavalier 2-door    4  112.0   88  2395  18.0  82  34.0
# 370         pontiac j2000 se hatchback    4  112.0   85  2575  16.2  82  31.0
# 371                     dodge aries se    4  135.0   84  2525  16.0  82  29.0
# 372                    pontiac phoenix    4  151.0   90  2735  18.0  82  27.0
# 373               ford fairmont futura    4  140.0   92  2865  16.4  82  24.0
# 374                     amc concord dl    4  151.0    ?  3035  20.5  82  23.0
# 375                volkswagen rabbit l    4  105.0   74  1980  15.3  82  36.0
# 376                 mazda glc custom l    4   91.0   68  2025  18.2  82  37.0
# 377                   mazda glc custom    4   91.0   68  1970  17.6  82  31.0
# 378             plymouth horizon miser    4  105.0   63  2125  14.7  82  38.0
# 379                     mercury lynx l    4   98.0   70  2125  17.3  82  36.0
# 380                   nissan stanza xe    4  120.0   88  2160  14.5  82  36.0
# 381                       honda accord    4  107.0   75  2205  14.5  82  36.0
# 382                     toyota corolla    4  108.0   70  2245  16.9  82  34.0
# 383                        honda civic    4   91.0   67  1965  15.0  82  38.0
# 384                 honda civic (auto)    4   91.0   67  1965  15.7  82  32.0
# 385                      datsun 310 gx    4   91.0   67  1995  16.2  82  38.0
# 386              buick century limited    6  181.0  110  2945  16.4  82  25.0
# 387  oldsmobile cutlass ciera (diesel)    6  262.0   85  3015  17.0  82  38.0
# 388         chrysler lebaron medallion    4  156.0   92  2585  14.5  82  26.0
# 389                     ford granada l    6  232.0  112  2835  14.7  82  22.0
# 390                   toyota celica gt    4  144.0   96  2665  13.9  82  32.0
# 391                  dodge charger 2.2    4  135.0   84  2370  13.0  82  36.0
# 392                   chevrolet camaro    4  151.0   90  2950  17.3  82  27.0
# 393                    ford mustang gl    4  140.0   86  2790  15.6  82  27.0
# 394                          vw pickup    4   97.0   52  2130  24.6  82  44.0
# 395                      dodge rampage    4  135.0   84  2295  11.6  82  32.0
# 396                        ford ranger    4  120.0   79  2625  18.6  82  28.0
# 397                         chevy s-10    4  119.0   82  2720  19.4  82  31.0
#
# [398 rows x 8 columns]

# %%
print(df.dtypes, df.shape)
# Out:
# car name     object
# cyl           int64
# disp        float64
# hp           object
# wt            int64
# acc         float64
# yr            int64
# mpg         float64
# dtype: object (398, 8)

# %%
df.describe().transpose()
# Out:
#       count         mean         std     min       25%     50%       75%  \
# cyl   398.0     5.454774    1.701004     3.0     4.000     4.0     8.000
# disp  398.0   193.425879  104.269838    68.0   104.250   148.5   262.000
# wt    398.0  2970.424623  846.841774  1613.0  2223.750  2803.5  3608.000
# acc   398.0    15.568090    2.757689     8.0    13.825    15.5    17.175
# yr    398.0    76.010050    3.697627    70.0    73.000    76.0    79.000
# mpg   398.0    23.514573    7.815984     9.0    17.500    23.0    29.000
#
#          max
# cyl      8.0
# disp   455.0
# wt    5140.0
# acc     24.8
# yr      82.0
# mpg     46.6

# %%
df = df.drop('car name',axis = 1)
df
# Out:
#      cyl   disp   hp    wt   acc  yr   mpg
# 0      8  307.0  130  3504  12.0  70  18.0
# 1      8  350.0  165  3693  11.5  70  15.0
# 2      8  318.0  150  3436  11.0  70  18.0
# 3      8  304.0  150  3433  12.0  70  16.0
# 4      8  302.0  140  3449  10.5  70  17.0
# 5      8  429.0  198  4341  10.0  70  15.0
# 6      8  454.0  220  4354   9.0  70  14.0
# 7      8  440.0  215  4312   8.5  70  14.0
# 8      8  455.0  225  4425  10.0  70  14.0
# 9      8  390.0  190  3850   8.5  70  15.0
# 10     8  383.0  170  3563  10.0  70  15.0
# 11     8  340.0  160  3609   8.0  70  14.0
# 12     8  400.0  150  3761   9.5  70  15.0
# 13     8  455.0  225  3086  10.0  70  14.0
# 14     4  113.0   95  2372  15.0  70  24.0
# 15     6  198.0   95  2833  15.5  70  22.0
# 16     6  199.0   97  2774  15.5  70  18.0
# 17     6  200.0   85  2587  16.0  70  21.0
# 18     4   97.0   88  2130  14.5  70  27.0
# 19     4   97.0   46  1835  20.5  70  26.0
# 20     4  110.0   87  2672  17.5  70  25.0
# 21     4  107.0   90  2430  14.5  70  24.0
# 22     4  104.0   95  2375  17.5  70  25.0
# 23     4  121.0  113  2234  12.5  70  26.0
# 24     6  199.0   90  2648  15.0  70  21.0
# 25     8  360.0  215  4615  14.0  70  10.0
# 26     8  307.0  200  4376  15.0  70  10.0
# 27     8  318.0  210  4382  13.5  70  11.0
# 28     8  304.0  193  4732  18.5  70   9.0
# 29     4   97.0   88  2130  14.5  71  27.0
# ..   ...    ...  ...   ...   ...  ..   ...
# 368    4  112.0   88  2640  18.6  82  27.0
# 369    4  112.0   88  2395  18.0  82  34.0
# 370    4  112.0   85  2575  16.2  82  31.0
# 371    4  135.0   84  2525  16.0  82  29.0
# 372    4  151.0   90  2735  18.0  82  27.0
# 373    4  140.0   92  2865  16.4  82  24.0
# 374    4  151.0    ?  3035  20.5  82  23.0
# 375    4  105.0   74  1980  15.3  82  36.0
# 376    4   91.0   68  2025  18.2  82  37.0
# 377    4   91.0   68  1970  17.6  82  31.0
# 378    4  105.0   63  2125  14.7  82  38.0
# 379    4   98.0   70  2125  17.3  82  36.0
# 380    4  120.0   88  2160  14.5  82  36.0
# 381    4  107.0   75  2205  14.5  82  36.0
# 382    4  108.0   70  2245  16.9  82  34.0
# 383    4   91.0   67  1965  15.0  82  38.0
# 384    4   91.0   67  1965  15.7  82  32.0
# 385    4   91.0   67  1995  16.2  82  38.0
# 386    6  181.0  110  2945  16.4  82  25.0
# 387    6  262.0   85  3015  17.0  82  38.0
# 388    4  156.0   92  2585  14.5  82  26.0
# 389    6  232.0  112  2835  14.7  82  22.0
# 390    4  144.0   96  2665  13.9  82  32.0
# 391    4  135.0   84  2370  13.0  82  36.0
# 392    4  151.0   90  2950  17.3  82  27.0
# 393    4  140.0   86  2790  15.6  82  27.0
# 394    4   97.0   52  2130  24.6  82  44.0
# 395    4  135.0   84  2295  11.6  82  32.0
# 396    4  120.0   79  2625  18.6  82  28.0
# 397    4  119.0   82  2720  19.4  82  31.0
#
# [398 rows x 7 columns]

# %%
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(10, 15))
sns.heatmap(df.corr(), annot=True, linewidths=.5, ax=ax,cmap="summer")

# %% [markdown]
# 2.	Use pair plot or scatter matrix to visualize how the different variables are related (Hint: The amount of Gaussian curves in the plot should give a visual identification of different clusters existing in the dataset) – 5 points

# %%
a = pd.scatter_matrix(df, figsize = (15,20))
# Out:
# C:\Anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
sns.pairplot(df)

# %%
3.	Use K Means or Hierarchical clustering to find out the optimal no of clusters in the data. Identify and separate the clusters (15 points)

# %%
#df['hp'] = df.hp.astype('float64')
df.hp = pd.to_numeric(df.hp, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 7 columns):
# cyl     398 non-null int64
# disp    398 non-null float64
# hp      392 non-null float64
# wt      398 non-null int64
# acc     398 non-null float64
# yr      398 non-null int64
# mpg     398 non-null float64
# dtypes: float64(4), int64(3)
# memory usage: 21.8 KB

# %%
#print (df.isnull().any(axis=1))
df[df['hp'].isnull()]
# Out:
#      cyl   disp  hp    wt   acc  yr   mpg
# 32     4   98.0 NaN  2046  19.0  71  25.0
# 126    6  200.0 NaN  2875  17.0  74  21.0
# 330    4   85.0 NaN  1835  17.3  80  40.9
# 336    4  140.0 NaN  2905  14.3  80  23.6
# 354    4  100.0 NaN  2320  15.8  81  34.5
# 374    4  151.0 NaN  3035  20.5  82  23.0

# %%
df['hp'] = df['hp'].fillna(df['hp'].mean(axis=0))

# %%
x=df.iloc[:,:].values

# %%
type(x)
x
# Out:
# array([[  8. , 307. , 130. , ...,  12. ,  70. ,  18. ],
#        [  8. , 350. , 165. , ...,  11.5,  70. ,  15. ],
#        [  8. , 318. , 150. , ...,  11. ,  70. ,  18. ],
#        ...,
#        [  4. , 135. ,  84. , ...,  11.6,  82. ,  32. ],
#        [  4. , 120. ,  79. , ...,  18.6,  82. ,  28. ],
#        [  4. , 119. ,  82. , ...,  19.4,  82. ,  31. ]])

# %%
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Fitting K-Means to the dataset
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(x)

# Visualising the clusters
plt.scatter(x[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(x[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(x[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(x[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 100, c = 'cyan', label = 'Cluster 4')
plt.scatter(x[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 100, c = 'magenta', label = 'Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a08caa4ca345> in <module>()
#       4
#       5 # Visualising the clusters
# ----> 6 plt.scatter(x[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
#       7 plt.scatter(x[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
#       8 plt.scatter(x[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
#
# NameError: name 'X' is not defined

# %%
4.	Use linear regression model on different clusters separately and print the coefficients of the models individually (7.5 points)
